# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Imputer

# %% [markdown]
# ## Load the 3 data sets from Word Data Bank
# ***
# ### Country dataframe

# %%
country = pd.DataFrame.from_csv('data/Country.csv', index_col = None)
country.head(2)
# Out:
#   CountryCode    ShortName    TableName                      LongName  \
# 0         AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 1         ALB      Albania      Albania           Republic of Albania
#
#   Alpha2Code    CurrencyUnit  \
# 0         AF  Afghan afghani
# 1         AL    Albanian lek
#
#                                         SpecialNotes                 Region  \
# 0  Fiscal year end: March 20; reporting period fo...             South Asia
# 1                                                NaN  Europe & Central Asia
#
#            IncomeGroup Wb2Code            ...             \
# 0           Low income      AF            ...
# 1  Upper middle income      AL            ...
#
#        GovernmentAccountingConcept              ImfDataDisseminationStandard  \
# 0  Consolidated central government  General Data Dissemination System (GDDS)
# 1     Budgetary central government  General Data Dissemination System (GDDS)
#
#   LatestPopulationCensus                              LatestHouseholdSurvey  \
# 0                   1979  Multiple Indicator Cluster Survey (MICS), 2010/11
# 1                   2011       Demographic and Health Survey (DHS), 2008/09
#
#           SourceOfMostRecentIncomeAndExpenditureData  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
#
#   VitalRegistrationComplete LatestAgriculturalCensus LatestIndustrialData  \
# 0                       NaN                  2013/14                  NaN
# 1                       Yes                     2012               2011.0
#
#   LatestTradeData LatestWaterWithdrawalData
# 0          2013.0                    2000.0
# 1          2013.0                    2006.0
#
# [2 rows x 31 columns]

# %%
country.shape
# Out:
# (247, 31)

# %% [markdown]
# The Country data frame has 31 descriptor columns for each of the 247 rows (countries of groups of countries). Let's get a sense for how many individual countries exist and how many aggregate groupings (e.g. world, regions, income groupings).

# %%
# ID aggregated rows by searching for 'aggregate' in the special notes column 
text = country.SpecialNotes.fillna('0')
len(text[text.str.contains('aggregate')])
# Out:
# 33

# %% [markdown]
# ### Load 'Series' dataframe (renamed as metrics)

# %%
metrics = pd.DataFrame.from_csv('data/Series.csv', index_col = None)

# %% [markdown]
# One row per series/metric, columns provide defintions, units, periodicity sources, etc. Now let's get a better sense for the key categories (and sub-categories) of development indicators.
#
# Interested in health/life expactancy as the target indicators. SP.DYN.LE00.IN is a good fit: Life expectancy at birth, total (years)

# %%
metrics[metrics.IndicatorName.str.contains('Life expectancy')].head()
# Out:
#             SeriesCode              Topic  \
# 818  SP.DYN.LE00.FE.IN  Health: Mortality
# 819  SP.DYN.LE00.MA.IN  Health: Mortality
# 820     SP.DYN.LE00.IN  Health: Mortality
#
#                                 IndicatorName  \
# 818  Life expectancy at birth, female (years)
# 819    Life expectancy at birth, male (years)
# 820   Life expectancy at birth, total (years)
#
#                                        ShortDefinition  \
# 818  Life expectancy at birth indicates the average...
# 819  Life expectancy at birth indicates the average...
# 820  Life expectancy at birth indicates the average...
#
#                                         LongDefinition UnitOfMeasure  \
# 818  Life expectancy at birth indicates the number ...           NaN
# 819  Life expectancy at birth indicates the number ...           NaN
# 820  Life expectancy at birth indicates the number ...           NaN
#
#     Periodicity BasePeriod  OtherNotes AggregationMethod  \
# 818      Annual        NaN         NaN  Weighted average
# 819      Annual        NaN         NaN  Weighted average
# 820      Annual        NaN         NaN  Weighted average
#
#                               LimitationsAndExceptions  \
# 818  Complete vital registration systems are not co...
# 819  Complete vital registration systems are not co...
# 820  Complete vital registration systems are not co...
#
#     NotesFromOriginalSource GeneralComments  \
# 818                     NaN             NaN
# 819                     NaN             NaN
# 820                     NaN             NaN
#
#                                                 Source  \
# 818  (1) United Nations Population Division. World ...
# 819  (1) United Nations Population Division. World ...
# 820  Derived from male and female life expectancy a...
#
#                       StatisticalConceptAndMethodology  \
# 818  Life expectancy at birth used here is the aver...
# 819  Life expectancy at birth used here is the aver...
# 820  Life expectancy at birth used here is the aver...
#
#                                   DevelopmentRelevance RelatedSourceLinks  \
# 818  Mortality rates for different age groups (infa...                NaN
# 819  Mortality rates for different age groups (infa...                NaN
# 820  Mortality rates for different age groups (infa...                NaN
#
#      OtherWebLinks  RelatedIndicators LicenseType
# 818            NaN                NaN        Open
# 819            NaN                NaN        Open
# 820            NaN                NaN        Open

# %% [markdown]
# Briefly view all the indicator categories that are available as predictors of Life Expectancy

# %%
# Highlevel topic categories
splitTopics = metrics.Topic.str.partition(':')
splitTopics.groupby([0,2]).size()
# Out:
# 0                          2
# Economic Policy & Debt      Balance of payments: Capital & financial account                              11
#                             Balance of payments: Current account: Balances                                 4
#                             Balance of payments: Current account: Goods, services & income                22
#                             Balance of payments: Current account: Transfers                                7
#                             Balance of payments: Reserves & other items                                    6
#                             External debt: Amortization                                                   18
#                             External debt: Arrears, reschedulings, etc.                                   22
#                             External debt: Commitments                                                     5
#                             External debt: Currency composition                                           10
#                             External debt: Debt outstanding                                               25
#                             External debt: Debt ratios & other items                                      17
#                             External debt: Debt service                                                   18
#                             External debt: Disbursements                                                  18
#                             External debt: Interest                                                       19
#                             External debt: Net flows                                                      27
#                             External debt: Net transfers                                                  17
#                             External debt: Terms                                                          12
#                             External debt: Undisbursed debt                                                3
#                             National accounts: Adjusted savings & income                                  28
#                             National accounts: Atlas GNI & GNI per capita                                  2
#                             National accounts: Growth rates                                               15
#                             National accounts: Growth rates:                                               2
#                             National accounts: Local currency at constant prices: Aggregate indicators     9
#                             National accounts: Local currency at constant prices: Expenditure on GDP      13
#                             National accounts: Local currency at constant prices: Other items              3
#                             National accounts: Local currency at constant prices: Value added              4
#                             National accounts: Local currency at current prices: Aggregate indicators      9
#                             National accounts: Local currency at current prices: Expenditure on GDP       14
#                             National accounts: Local currency at current prices: Value added               4
#                             National accounts: Shares of GDP & other                                      24
#                                                                                                           ..
# Health                      Population: Dynamics                                                          11
#                             Population: Structure                                                          5
#                             Reproductive health                                                           14
#                             Risk factors                                                                  15
# Infrastructure              Communications                                                                13
#                             Technology                                                                    11
#                             Transportation                                                                12
# Poverty                     Income distribution                                                            8
#                             Poverty rates                                                                 10
#                             Shared prosperity                                                              6
# Private Sector & Trade      Business environment                                                          48
#                             Exports                                                                       24
#                             Imports                                                                       22
#                             Private infrastructure investment                                              4
#                             Tariffs                                                                       24
#                             Total merchandise trade                                                        1
#                             Trade facilitation                                                            13
#                             Trade indexes                                                                  5
#                             Travel & tourism                                                              10
# Public Sector               Conflict & fragility                                                           5
#                             Defense & arms trade                                                           7
#                             Government finance: Deficit & financing                                        8
#                             Government finance: Expense                                                   13
#                             Government finance: Revenue                                                   22
#                             Policy & institutions                                                         27
# Social Protection & Labor   Economic activity                                                             75
#                             Labor force structure                                                         28
#                             Migration                                                                      6
#                             Performance                                                                   12
#                             Unemployment                                                                  27
# dtype: int64

# %% [markdown]
# ### Load 'Indicators' dataframe (renamed as 'df')
# ***

# %%
df = pd.DataFrame.from_csv('data/indicators.csv', index_col=None)

#check availability of data and how missing values are handled (confirm unavailable data reported as'NaN')
df[df.IndicatorName.str.contains('GDP per capita')].groupby(['CountryName', 'IndicatorName']).size().unstack()
# Out:
# IndicatorName           GDP per capita (constant 2005 US$)  \
# CountryName
# Afghanistan                                           13.0
# Albania                                               35.0
# Algeria                                               55.0
# American Samoa                                         NaN
# Andorra                                               44.0
# Angola                                                 1.0
# Antigua and Barbuda                                   38.0
# Arab World                                            40.0
# Argentina                                             55.0
# Armenia                                               25.0
# Aruba                                                 16.0
# Australia                                             55.0
# Austria                                               55.0
# Azerbaijan                                            25.0
# Bahamas, The                                          55.0
# Bahrain                                               35.0
# Bangladesh                                            55.0
# Barbados                                              35.0
# Belarus                                               25.0
# Belgium                                               55.0
# Belize                                                55.0
# Benin                                                 55.0
# Bermuda                                               54.0
# Bhutan                                                35.0
# Bolivia                                               55.0
# Bosnia and Herzegovina                                21.0
# Botswana                                              55.0
# Brazil                                                55.0
# Brunei Darussalam                                     41.0
# Bulgaria                                              35.0
# ...                                                    ...
# Switzerland                                           35.0
# Syrian Arab Republic                                  48.0
# Tajikistan                                            30.0
# Tanzania                                              27.0
# Thailand                                              55.0
# Timor-Leste                                           16.0
# Togo                                                  55.0
# Tonga                                                 34.0
# Trinidad and Tobago                                   55.0
# Tunisia                                               50.0
# Turkey                                                55.0
# Turkmenistan                                          28.0
# Tuvalu                                                25.0
# Uganda                                                33.0
# Ukraine                                               28.0
# United Arab Emirates                                  40.0
# United Kingdom                                        55.0
# United States                                         55.0
# Upper middle income                                   55.0
# Uruguay                                               55.0
# Uzbekistan                                            28.0
# Vanuatu                                               36.0
# Venezuela, RB                                         55.0
# Vietnam                                               31.0
# Virgin Islands (U.S.)                                  NaN
# West Bank and Gaza                                    21.0
# World                                                 55.0
# Yemen, Rep.                                           24.0
# Zambia                                                55.0
# Zimbabwe                                              55.0
#
# IndicatorName           GDP per capita (constant LCU)  \
# CountryName
# Afghanistan                                      13.0
# Albania                                          35.0
# Algeria                                          55.0
# American Samoa                                    NaN
# Andorra                                          44.0
# Angola                                           18.0
# Antigua and Barbuda                              38.0
# Arab World                                        NaN
# Argentina                                        55.0
# Armenia                                          25.0
# Aruba                                            16.0
# Australia                                        55.0
# Austria                                          55.0
# Azerbaijan                                       25.0
# Bahamas, The                                     55.0
# Bahrain                                          35.0
# Bangladesh                                       55.0
# Barbados                                         35.0
# Belarus                                          25.0
# Belgium                                          55.0
# Belize                                           55.0
# Benin                                            55.0
# Bermuda                                          54.0
# Bhutan                                           35.0
# Bolivia                                          55.0
# Bosnia and Herzegovina                           21.0
# Botswana                                         55.0
# Brazil                                           55.0
# Brunei Darussalam                                41.0
# Bulgaria                                         35.0
# ...                                               ...
# Switzerland                                      35.0
# Syrian Arab Republic                             48.0
# Tajikistan                                       30.0
# Tanzania                                         27.0
# Thailand                                         55.0
# Timor-Leste                                      16.0
# Togo                                             55.0
# Tonga                                            34.0
# Trinidad and Tobago                              55.0
# Tunisia                                          50.0
# Turkey                                           55.0
# Turkmenistan                                     28.0
# Tuvalu                                           25.0
# Uganda                                           33.0
# Ukraine                                          28.0
# United Arab Emirates                             40.0
# United Kingdom                                   55.0
# United States                                    55.0
# Upper middle income                               NaN
# Uruguay                                          55.0
# Uzbekistan                                       28.0
# Vanuatu                                          36.0
# Venezuela, RB                                    55.0
# Vietnam                                          31.0
# Virgin Islands (U.S.)                            20.0
# West Bank and Gaza                               21.0
# World                                             NaN
# Yemen, Rep.                                      24.0
# Zambia                                           55.0
# Zimbabwe                                         55.0
#
# IndicatorName           GDP per capita (current LCU)  \
# CountryName
# Afghanistan                                     36.0
# Albania                                         35.0
# Algeria                                         55.0
# American Samoa                                   NaN
# Andorra                                         44.0
# Angola                                          29.0
# Antigua and Barbuda                             38.0
# Arab World                                       NaN
# Argentina                                       55.0
# Armenia                                         25.0
# Aruba                                           18.0
# Australia                                       55.0
# Austria                                         55.0
# Azerbaijan                                      25.0
# Bahamas, The                                    55.0
# Bahrain                                         35.0
# Bangladesh                                      55.0
# Barbados                                        35.0
# Belarus                                         25.0
# Belgium                                         55.0
# Belize                                          55.0
# Benin                                           55.0
# Bermuda                                         54.0
# Bhutan                                          35.0
# Bolivia                                         55.0
# Bosnia and Herzegovina                          21.0
# Botswana                                        55.0
# Brazil                                          55.0
# Brunei Darussalam                               50.0
# Bulgaria                                        35.0
# ...                                              ...
# Switzerland                                     45.0
# Syrian Arab Republic                            48.0
# Tajikistan                                      30.0
# Tanzania                                        27.0
# Thailand                                        55.0
# Timor-Leste                                     15.0
# Togo                                            55.0
# Tonga                                           40.0
# Trinidad and Tobago                             55.0
# Tunisia                                         50.0
# Turkey                                          55.0
# Turkmenistan                                    28.0
# Tuvalu                                          25.0
# Uganda                                          55.0
# Ukraine                                         55.0
# United Arab Emirates                            40.0
# United Kingdom                                  55.0
# United States                                   55.0
# Upper middle income                              NaN
# Uruguay                                         55.0
# Uzbekistan                                      28.0
# Vanuatu                                         36.0
# Venezuela, RB                                   54.0
# Vietnam                                         30.0
# Virgin Islands (U.S.)                           34.0
# West Bank and Gaza                              21.0
# World                                            NaN
# Yemen, Rep.                                     24.0
# Zambia                                          55.0
# Zimbabwe                                        55.0
#
# IndicatorName           GDP per capita (current US$)  \
# CountryName
# Afghanistan                                     36.0
# Albania                                         31.0
# Algeria                                         55.0
# American Samoa                                   NaN
# Andorra                                         44.0
# Angola                                          29.0
# Antigua and Barbuda                             38.0
# Arab World                                      47.0
# Argentina                                       53.0
# Armenia                                         25.0
# Aruba                                           18.0
# Australia                                       55.0
# Austria                                         55.0
# Azerbaijan                                      25.0
# Bahamas, The                                    55.0
# Bahrain                                         35.0
# Bangladesh                                      55.0
# Barbados                                        35.0
# Belarus                                         25.0
# Belgium                                         55.0
# Belize                                          55.0
# Benin                                           55.0
# Bermuda                                         54.0
# Bhutan                                          35.0
# Bolivia                                         55.0
# Bosnia and Herzegovina                          21.0
# Botswana                                        55.0
# Brazil                                          55.0
# Brunei Darussalam                               50.0
# Bulgaria                                        35.0
# ...                                              ...
# Switzerland                                     45.0
# Syrian Arab Republic                            48.0
# Tajikistan                                      25.0
# Tanzania                                        27.0
# Thailand                                        55.0
# Timor-Leste                                     15.0
# Togo                                            55.0
# Tonga                                           40.0
# Trinidad and Tobago                             55.0
# Tunisia                                         50.0
# Turkey                                          55.0
# Turkmenistan                                    28.0
# Tuvalu                                          25.0
# Uganda                                          55.0
# Ukraine                                         28.0
# United Arab Emirates                            40.0
# United Kingdom                                  55.0
# United States                                   55.0
# Upper middle income                             55.0
# Uruguay                                         55.0
# Uzbekistan                                      25.0
# Vanuatu                                         36.0
# Venezuela, RB                                   53.0
# Vietnam                                         30.0
# Virgin Islands (U.S.)                           34.0
# West Bank and Gaza                              21.0
# World                                           55.0
# Yemen, Rep.                                     24.0
# Zambia                                          55.0
# Zimbabwe                                        55.0
#
# IndicatorName           GDP per capita growth (annual %)  \
# CountryName
# Afghanistan                                         12.0
# Albania                                             34.0
# Algeria                                             54.0
# American Samoa                                       NaN
# Andorra                                             43.0
# Angola                                              17.0
# Antigua and Barbuda                                 37.0
# Arab World                                          39.0
# Argentina                                           54.0
# Armenia                                             24.0
# Aruba                                               15.0
# Australia                                           54.0
# Austria                                             54.0
# Azerbaijan                                          24.0
# Bahamas, The                                        54.0
# Bahrain                                             34.0
# Bangladesh                                          54.0
# Barbados                                            34.0
# Belarus                                             24.0
# Belgium                                             54.0
# Belize                                              54.0
# Benin                                               54.0
# Bermuda                                             53.0
# Bhutan                                              34.0
# Bolivia                                             54.0
# Bosnia and Herzegovina                              20.0
# Botswana                                            54.0
# Brazil                                              54.0
# Brunei Darussalam                                   40.0
# Bulgaria                                            34.0
# ...                                                  ...
# Switzerland                                         34.0
# Syrian Arab Republic                                47.0
# Tajikistan                                          29.0
# Tanzania                                            26.0
# Thailand                                            54.0
# Timor-Leste                                         15.0
# Togo                                                54.0
# Tonga                                               33.0
# Trinidad and Tobago                                 54.0
# Tunisia                                             49.0
# Turkey                                              54.0
# Turkmenistan                                        27.0
# Tuvalu                                              24.0
# Uganda                                              32.0
# Ukraine                                             27.0
# United Arab Emirates                                39.0
# United Kingdom                                      54.0
# United States                                       54.0
# Upper middle income                                 54.0
# Uruguay                                             54.0
# Uzbekistan                                          27.0
# Vanuatu                                             35.0
# Venezuela, RB                                       54.0
# Vietnam                                             30.0
# Virgin Islands (U.S.)                               19.0
# West Bank and Gaza                                  20.0
# World                                               54.0
# Yemen, Rep.                                         23.0
# Zambia                                              54.0
# Zimbabwe                                            54.0
#
# IndicatorName           GDP per capita, PPP (constant 2011 international $)  \
# CountryName
# Afghanistan                                                          13.0
# Albania                                                              25.0
# Algeria                                                              25.0
# American Samoa                                                        NaN
# Andorra                                                               NaN
# Angola                                                                1.0
# Antigua and Barbuda                                                  25.0
# Arab World                                                           25.0
# Argentina                                                             NaN
# Armenia                                                              25.0
# Aruba                                                                 1.0
# Australia                                                            25.0
# Austria                                                              25.0
# Azerbaijan                                                           25.0
# Bahamas, The                                                         25.0
# Bahrain                                                              25.0
# Bangladesh                                                           25.0
# Barbados                                                             25.0
# Belarus                                                              25.0
# Belgium                                                              25.0
# Belize                                                               25.0
# Benin                                                                25.0
# Bermuda                                                              24.0
# Bhutan                                                               25.0
# Bolivia                                                              25.0
# Bosnia and Herzegovina                                               21.0
# Botswana                                                             25.0
# Brazil                                                               25.0
# Brunei Darussalam                                                    25.0
# Bulgaria                                                             25.0
# ...                                                                   ...
# Switzerland                                                          25.0
# Syrian Arab Republic                                                  NaN
# Tajikistan                                                           25.0
# Tanzania                                                             25.0
# Thailand                                                             25.0
# Timor-Leste                                                          16.0
# Togo                                                                 25.0
# Tonga                                                                25.0
# Trinidad and Tobago                                                  25.0
# Tunisia                                                              25.0
# Turkey                                                               25.0
# Turkmenistan                                                         25.0
# Tuvalu                                                               25.0
# Uganda                                                               25.0
# Ukraine                                                              25.0
# United Arab Emirates                                                 25.0
# United Kingdom                                                       25.0
# United States                                                        25.0
# Upper middle income                                                  25.0
# Uruguay                                                              25.0
# Uzbekistan                                                           25.0
# Vanuatu                                                              25.0
# Venezuela, RB                                                        25.0
# Vietnam                                                              25.0
# Virgin Islands (U.S.)                                                 NaN
# West Bank and Gaza                                                   21.0
# World                                                                25.0
# Yemen, Rep.                                                          24.0
# Zambia                                                               25.0
# Zimbabwe                                                             25.0
#
# IndicatorName           GDP per capita, PPP (current international $)  \
# CountryName
# Afghanistan                                                      13.0
# Albania                                                          25.0
# Algeria                                                          25.0
# American Samoa                                                    NaN
# Andorra                                                           NaN
# Angola                                                            1.0
# Antigua and Barbuda                                              25.0
# Arab World                                                       25.0
# Argentina                                                         NaN
# Armenia                                                          25.0
# Aruba                                                             1.0
# Australia                                                        25.0
# Austria                                                          25.0
# Azerbaijan                                                       25.0
# Bahamas, The                                                     25.0
# Bahrain                                                          25.0
# Bangladesh                                                       25.0
# Barbados                                                         25.0
# Belarus                                                          25.0
# Belgium                                                          25.0
# Belize                                                           25.0
# Benin                                                            25.0
# Bermuda                                                          24.0
# Bhutan                                                           25.0
# Bolivia                                                          25.0
# Bosnia and Herzegovina                                           21.0
# Botswana                                                         25.0
# Brazil                                                           25.0
# Brunei Darussalam                                                25.0
# Bulgaria                                                         25.0
# ...                                                               ...
# Switzerland                                                      25.0
# Syrian Arab Republic                                              NaN
# Tajikistan                                                       25.0
# Tanzania                                                         25.0
# Thailand                                                         25.0
# Timor-Leste                                                      15.0
# Togo                                                             25.0
# Tonga                                                            25.0
# Trinidad and Tobago                                              25.0
# Tunisia                                                          25.0
# Turkey                                                           25.0
# Turkmenistan                                                     25.0
# Tuvalu                                                           25.0
# Uganda                                                           25.0
# Ukraine                                                          25.0
# United Arab Emirates                                             25.0
# United Kingdom                                                   25.0
# United States                                                    25.0
# Upper middle income                                              25.0
# Uruguay                                                          25.0
# Uzbekistan                                                       25.0
# Vanuatu                                                          25.0
# Venezuela, RB                                                    24.0
# Vietnam                                                          25.0
# Virgin Islands (U.S.)                                             NaN
# West Bank and Gaza                                               21.0
# World                                                            25.0
# Yemen, Rep.                                                      24.0
# Zambia                                                           25.0
# Zimbabwe                                                         25.0
#
# IndicatorName           Government expenditure per primary student as % of GDP per capita (%)  \
# CountryName
# Afghanistan                                                           NaN
# Albania                                                               NaN
# Algeria                                                               4.0
# American Samoa                                                        NaN
# Andorra                                                               9.0
# Angola                                                                NaN
# Antigua and Barbuda                                                   1.0
# Arab World                                                            NaN
# Argentina                                                            15.0
# Armenia                                                               1.0
# Aruba                                                                 6.0
# Australia                                                             9.0
# Austria                                                              14.0
# Azerbaijan                                                            NaN
# Bahamas, The                                                          NaN
# Bahrain                                                               1.0
# Bangladesh                                                            4.0
# Barbados                                                              8.0
# Belarus                                                               NaN
# Belgium                                                              12.0
# Belize                                                                9.0
# Benin                                                                12.0
# Bermuda                                                               3.0
# Bhutan                                                                7.0
# Bolivia                                                              12.0
# Bosnia and Herzegovina                                                NaN
# Botswana                                                              3.0
# Brazil                                                               12.0
# Brunei Darussalam                                                     1.0
# Bulgaria                                                             12.0
# ...                                                                   ...
# Switzerland                                                           5.0
# Syrian Arab Republic                                                  7.0
# Tajikistan                                                            NaN
# Tanzania                                                              6.0
# Thailand                                                              9.0
# Timor-Leste                                                           NaN
# Togo                                                                 16.0
# Tonga                                                                 3.0
# Trinidad and Tobago                                                   7.0
# Tunisia                                                               8.0
# Turkey                                                                NaN
# Turkmenistan                                                          NaN
# Tuvalu                                                                NaN
# Uganda                                                                5.0
# Ukraine                                                               2.0
# United Arab Emirates                                                  3.0
# United Kingdom                                                       14.0
# United States                                                        15.0
# Upper middle income                                                   NaN
# Uruguay                                                               8.0
# Uzbekistan                                                            NaN
# Vanuatu                                                               6.0
# Venezuela, RB                                                         3.0
# Vietnam                                                               3.0
# Virgin Islands (U.S.)                                                 NaN
# West Bank and Gaza                                                    NaN
# World                                                                 NaN
# Yemen, Rep.                                                           2.0
# Zambia                                                                3.0
# Zimbabwe                                                              NaN
#
# IndicatorName           Government expenditure per secondary student as % of GDP per capita (%)  \
# CountryName
# Afghanistan                                                           NaN
# Albania                                                               NaN
# Algeria                                                               4.0
# American Samoa                                                        3.0
# Andorra                                                               9.0
# Angola                                                                NaN
# Antigua and Barbuda                                                   2.0
# Arab World                                                            NaN
# Argentina                                                            15.0
# Armenia                                                               1.0
# Aruba                                                                 6.0
# Australia                                                             9.0
# Austria                                                              14.0
# Azerbaijan                                                            NaN
# Bahamas, The                                                          NaN
# Bahrain                                                               1.0
# Bangladesh                                                           11.0
# Barbados                                                             11.0
# Belarus                                                               NaN
# Belgium                                                              12.0
# Belize                                                                9.0
# Benin                                                                 7.0
# Bermuda                                                               3.0
# Bhutan                                                                5.0
# Bolivia                                                              12.0
# Bosnia and Herzegovina                                                NaN
# Botswana                                                              3.0
# Brazil                                                                9.0
# Brunei Darussalam                                                     2.0
# Bulgaria                                                             12.0
# ...                                                                   ...
# Switzerland                                                           5.0
# Syrian Arab Republic                                                  7.0
# Tajikistan                                                            NaN
# Tanzania                                                              1.0
# Thailand                                                              8.0
# Timor-Leste                                                           NaN
# Togo                                                                  4.0
# Tonga                                                                 3.0
# Trinidad and Tobago                                                   NaN
# Tunisia                                                               8.0
# Turkey                                                                NaN
# Turkmenistan                                                          NaN
# Tuvalu                                                                NaN
# Uganda                                                                5.0
# Ukraine                                                               2.0
# United Arab Emirates                                                  3.0
# United Kingdom                                                       14.0
# United States                                                        15.0
# Upper middle income                                                   NaN
# Uruguay                                                               8.0
# Uzbekistan                                                            NaN
# Vanuatu                                                               3.0
# Venezuela, RB                                                         3.0
# Vietnam                                                               NaN
# Virgin Islands (U.S.)                                                 NaN
# West Bank and Gaza                                                    NaN
# World                                                                 NaN
# Yemen, Rep.                                                           2.0
# Zambia                                                                NaN
# Zimbabwe                                                              NaN
#
# IndicatorName           Government expenditure per tertiary student as % of GDP per capita (%)
# CountryName
# Afghanistan                                                           NaN
# Albania                                                               NaN
# Algeria                                                               NaN
# American Samoa                                                        NaN
# Andorra                                                               5.0
# Angola                                                                2.0
# Antigua and Barbuda                                                   1.0
# Arab World                                                            NaN
# Argentina                                                            15.0
# Armenia                                                               6.0
# Aruba                                                                 6.0
# Australia                                                             8.0
# Austria                                                              14.0
# Azerbaijan                                                            6.0
# Bahamas, The                                                          NaN
# Bahrain                                                               1.0
# Bangladesh                                                           11.0
# Barbados                                                              6.0
# Belarus                                                               9.0
# Belgium                                                              12.0
# Belize                                                                5.0
# Benin                                                                11.0
# Bermuda                                                               4.0
# Bhutan                                                                5.0
# Bolivia                                                               6.0
# Bosnia and Herzegovina                                                NaN
# Botswana                                                              3.0
# Brazil                                                               13.0
# Brunei Darussalam                                                     2.0
# Bulgaria                                                             12.0
# ...                                                                   ...
# Switzerland                                                           5.0
# Syrian Arab Republic                                                  7.0
# Tajikistan                                                           12.0
# Tanzania                                                              3.0
# Thailand                                                             11.0
# Timor-Leste                                                           2.0
# Togo                                                                  6.0
# Tonga                                                                 2.0
# Trinidad and Tobago                                                   NaN
# Tunisia                                                               6.0
# Turkey                                                                6.0
# Turkmenistan                                                          NaN
# Tuvalu                                                                NaN
# Uganda                                                                5.0
# Ukraine                                                              12.0
# United Arab Emirates                                                  NaN
# United Kingdom                                                       14.0
# United States                                                        13.0
# Upper middle income                                                   NaN
# Uruguay                                                               8.0
# Uzbekistan                                                            NaN
# Vanuatu                                                               3.0
# Venezuela, RB                                                         1.0
# Vietnam                                                               3.0
# Virgin Islands (U.S.)                                                 NaN
# West Bank and Gaza                                                    NaN
# World                                                                 NaN
# Yemen, Rep.                                                           NaN
# Zambia                                                                1.0
# Zimbabwe                                                              1.0
#
# [241 rows x 10 columns]

# %% [markdown]
# ## Data wrangling & inferential statistics
# ***

# %% [markdown]
# ### Plot life expectancy trends for high, med, and low income countries

# %%
income = country[['CountryCode','IncomeGroup', 'SpecialNotes']]
df_Le = df.merge(income, left_on=df.CountryCode, right_on = income.CountryCode, how='outer')
df_Le = df_Le[(df_Le.IndicatorName =='Life expectancy at birth, total (years)') 
                              & (df_Le.SpecialNotes.str.contains('aggregate'))]

df_Le = pd.pivot_table(df_Le, values = 'Value', index='Year', columns='CountryName')

# %%
income_grps = ['World', 'High income', 'Middle income', 'Low income']

df_Le[income_grps].plot(figsize=(15,5))
plt.title('Life Expectancy, by income level')
plt.ylabel('Life Expectancy (years)')

# %%
regions = ['North America','European Union','Central Europe and the Baltics', 
        'Latin America & Caribbean (all income levels)','World',
        'East Asia & Pacific (all income levels)','Arab World',  
        'South Asia', 'Sub-Saharan Africa (all income levels)']

df_Le[regions].plot(figsize=(15,5))
plt.title('Life Expectancy, by Region')
plt.ylabel('Life Expectancy (years)')
plt.show()

# %%
# Plot 2013 life expectancy for all countries, by income grouping
df_2013 = df.merge(income, left_on=df.CountryCode, right_on = income.CountryCode, how='outer')

df_2013 = df_2013[(df_2013.IndicatorName =='Life expectancy at birth, total (years)') & (df_2013.Year == 2013)]

sns.set_style("whitegrid")
# fig.set_style
plt.figure(figsize=(16, 6))
_ = sns.swarmplot(x='IncomeGroup', y = 'Value', data = df_2013)
_ = plt.xlabel('Income Group')
_ = plt.ylabel('Life Expectancy')
_ = plt.title('2013 Life expectancy by country income grouping')

plt.show()

# %%
df_2013.groupby(['IncomeGroup']).describe().unstack()
# Out:
#                      Value                                             \
#                      count       mean       std        min        25%
# IncomeGroup
# High income: OECD     32.0  80.635077  2.010744  75.268293  80.355488
# High income: nonOECD  36.0  76.792581  4.570202  57.290829  74.920841
# Low income            31.0  59.531009  5.020727  49.879878  55.942305
# Lower middle income   51.0  66.887601  6.665756  48.937927  63.375280
# Upper middle income   48.0  72.507274  5.290481  51.866171  70.915787
#
#                                                        Year               \
#                             50%        75%        max count    mean  std
# IncomeGroup
# High income: OECD     81.074390  81.840244  83.331951  32.0  2013.0  0.0
# High income: nonOECD  76.981500  79.705738  83.831707  36.0  2013.0  0.0
# Low income            59.312024  63.055024  69.791951  31.0  2013.0  0.0
# Lower middle income   68.131561  71.577817  75.756488  51.0  2013.0  0.0
# Upper middle income   74.011927  75.146427  80.128878  48.0  2013.0  0.0
#
#
#                          min     25%     50%     75%     max
# IncomeGroup
# High income: OECD     2013.0  2013.0  2013.0  2013.0  2013.0
# High income: nonOECD  2013.0  2013.0  2013.0  2013.0  2013.0
# Low income            2013.0  2013.0  2013.0  2013.0  2013.0
# Lower middle income   2013.0  2013.0  2013.0  2013.0  2013.0
# Upper middle income   2013.0  2013.0  2013.0  2013.0  2013.0

# %% [markdown]
# ### Machine learning: Predicting life expectancy with linear regression

# %%
columns = {"SP.DYN.LE00.IN": "LifeExpect_total",
            "SH.XPD.PCAP": "HealthExp_perCap",
            "NY.ADJ.AEDU.GN.ZS": "EduExp_percentGNI",
            'NY.ADJ.NNTY.KD.ZG': 'Adj_nat_income_%dlt',
            'SP.ADO.TFRT': 'Adol_fertility',
            'AG.LND.AGRI.ZS': 'Agri_land_perc',
#             'AG.LND.ARBL.ZS': 'Arable_land_perc',
            'MS.MIL.TOTL.TF.ZS': 'Armed_forces_perc',
            'SL.EMP.1524.SP.ZS': 'Employ_ratio_15',
            'SE.PRM.ENRR': 'Primary_edu',
            'SE.PRM.ENRL': 'Secondary_edu',
            'NY.GDP.PCAP.CD': 'GDP_per_capita_US$',
            'SH.XPD.TOTL.ZS': 'Health_exp_perc',
            'NE.IMP.GNFS.ZS': 'Imports_perGDP',
            'SH.STA.ACSN': 'Sanitation_perc_access',
            'NV.IND.TOTL.ZS': 'Industry_percGDP',
            'SH.MMR.RISK': 'Maternal_death_perc',
            'IT.CEL.SETS.P2': 'Mobile_phone_per100',
            'SP.DYN.IMRT.IN': 'Mortality_infant _per1000',
            'SH.DYN.NMRT': 'Mortality_neonatal_1000',
            'SH.DYN.MORT': 'Mortality_sub5_1000',
            'EN.POP.DNST': 'Pop_density',
            'SM.POP.REFG': 'Refugee_population',
            'SP.RUR.TOTL.ZS': 'Rural_population_per',
            'NE.TRD.GNFS.ZS': 'Trade_percGDP',
            'SL.UEM.TOTL.ZS': 'Unemployment_perc'}

# %%
df.IndicatorCode = df.IndicatorCode.astype(str)
df.IndicatorName = df.IndicatorName.astype(str)

# piovt the 2013 data so the features are column headers
pivot = df[df.Year==2013].pivot_table('Value','CountryName', 'IndicatorCode')

features = list(columns.keys())

# columns={"SP.DYN.LE00.IN": "LifeExpect_total",
#          "NY.GDP.PCAP.KD": "GDP_perCap", 
#          "SH.XPD.PCAP": "HealthExp_perCap",
#          "NY.ADJ.AEDU.GN.ZS": "EduExp_percentGNI"}

df_features = pivot[features]
df_features.columns = df_features.columns.to_series()
flattened = pd.DataFrame(df_features.to_records())

df_ml = flattened.rename(index=str, columns=columns)

# Drop countries who do not have a life expectancy value 
df_ml = df_ml[pd.notnull(df_ml.LifeExpect_total)]
df_ml = df_ml.dropna(axis =0, how='any').drop('CountryName', axis = 1)

# %%
corr = df_ml.corr()
ax = sns.heatmap(corr)

# %%
y = df_ml.LifeExpect_total.values.reshape(-1,1)
X = df_ml.drop(['LifeExpect_total'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42) 
lr = LinearRegression(normalize=True)

lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr.score(X_test, y_test)
# Out:
# 0.87200968682710878
